# %%
import pandas as pd

# Load datasets
listings = pd.read_csv("C:\Users\thoka\Downloads\Airbnb project\data\raw\listings.csv")
reviews = pd.read_csv("C:\Users\thoka\Downloads\Airbnb project\data\raw\reviews.csv")
calendar = pd.read_csv("C:\Users\thoka\Downloads\Airbnb project\data\raw\calendar.csv")

# Check shape
print("Listings:", listings.shape)
print("Reviews:", reviews.shape)
print("Calendar:", calendar.shape)

# Preview data
listings.head()

# %%
# Basic info
listings.info()
reviews.info()
calendar.info()

# %%
# Missing values
listings.isnull().sum()
